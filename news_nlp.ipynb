# %%
import os
import numpy as np
import pandas as pd

# %%
DATA = "/Volumes/PAULHD2/tweets/data/"
TOP_FOLDERS = ['domestic_security/', 'short_terrorism/']

# %%
#List the paths to all articles in the data folder
paths = []
for folder in TOP_FOLDERS:
    for filename in os.listdir(DATA + folder):
        if filename.endswith('.csv'):
            #articles.append(filename.split('.csv')[0]) #Extract article name from the filename
            paths.append(DATA + folder + filename)

# %%
df = pd.read_csv(paths[1], index_col=0)
# Out:
# /Applications/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3051: DtypeWarning: Columns (23) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
paths[1]
# Out:
# '/Volumes/PAULHD2/tweets/data/domestic_security/air_marshal.csv'

# %%
tweets = df.language.to_frame()
tweets
# Out:
#                                                   tweet
# 0     @stephenrodrick but what if Ed were actually a...
# 1     ISLAMABAD: Air Marshal Tahir Rafique Butt ko n...
# 2     The Air Marshal  once said "No one will want t...
# 3     @Brittany_714 I'm not an air marshal. Liar!!! ...
# 4     Agent task force air marshal assassination att...
# ...                                                 ...
# 4590  "@McPakerr_MB: These dumb Cameroon niggas be i...
# 4591  Tbf, only a few African countries shld be allo...
# 4592  All dis ones from some next dead African count...
# 4593  @iFirstBorn_ @_Sholaaa_ @Lloyd_Oski wtf did so...
# 4594     Before AIPSC training🙌  http://t.co/7ZwweC9zU5
#
# [42359 rows x 1 columns]

# %%
print(len(df))
df[df.language != 'en']
# Out:
# 42359
#                       id     conversation_id               created_at  \
# 1     174627287105417217  174627287105417217  2012-02-28 22:49:24 UTC
# 6     174602380309045248  174602380309045248  2012-02-28 21:10:26 UTC
# 13    174587911675707392  174587911675707392  2012-02-28 20:12:56 UTC
# 21    174575676106612736  174575676106612736  2012-02-28 19:24:19 UTC
# 22    174575673128652804  174575673128652804  2012-02-28 19:24:18 UTC
# ...                  ...                 ...                      ...
# 4545  385904060551168001  385898511105277952  2013-10-03 23:07:52 UTC
# 4564  385115255577509888  385115255577509888  2013-10-01 18:53:26 UTC
# 4582  384855320293806080  384849506103488512  2013-10-01 01:40:33 UTC
# 4583  384855236822958080  384854284548210689  2013-10-01 01:40:13 UTC
# 4589  384851436892618752  384850993805922305  2013-10-01 01:25:07 UTC
#
#             date      time  timezone     user_id         username  \
# ...
